# %% [markdown]
# <a href="https://colab.research.google.com/github/NajibxTheJib/WBS_project2_Eniac/blob/main/Project_2_Data_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #IMPORT DATAFRAME

# %%
import pandas as pd
import numpy as np

# orderslines
url = "https://drive.google.com/file/d/1FYhN_2AzTBFuWcfHaRuKcuCE6CWXsWtG/view?usp=sharing" # orderlines.csv
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
orderslines = pd.read_csv(path)

# orders
url = "https://drive.google.com/file/d/1Vu0q91qZw6lqhIqbjoXYvYAQTmVHh6uZ/view?usp=drive_link" # orderlines.csv
path1 = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
orders = pd.read_csv(path1)

# brands
url = "https://drive.google.com/file/d/1m1ThDDIYRTTii-rqM5SEQjJ8McidJskD/view?usp=drive_link" # orderlines.csv
path2 = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
brands = pd.read_csv(path2)

# products
url = "https://drive.google.com/file/d/1afxwDXfl-7cQ_qLwyDitfcCx3u7WMvkU/view?usp=drive_link" # orderlines.csv
path3 = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
products = pd.read_csv(path3)

# %% [markdown]
# #ORDERS TABLE INFO

# %%
orders
# Out:
#         order_id         created_date  total_paid            state
# 0         241319  2017-01-02 13:35:40       44.99        Cancelled
# 1         241423  2017-11-06 13:10:02      136.15        Completed
# 2         242832  2017-12-31 17:40:03       15.76        Completed
# 3         243330  2017-02-16 10:59:38       84.98        Completed
# 4         243784  2017-11-24 13:35:19      157.86        Cancelled
# ...          ...                  ...         ...              ...
# 226904    527397  2018-03-14 13:56:38       42.99      Place Order
# 226905    527398  2018-03-14 13:57:25       42.99  Shopping Basket
# 226906    527399  2018-03-14 13:57:34      141.58  Shopping Basket
# 226907    527400  2018-03-14 13:57:41       19.98  Shopping Basket
# 226908    527401  2018-03-14 13:58:36       18.98      Place Order
#
# [226909 rows x 4 columns]

# %%
orders.size
# Out:
# 907636

# %%
orders.shape[0] * orders.shape[1] == orders.size
# Out:
# True

# %%
orders.head()
# Out:
#    order_id         created_date  total_paid      state
# 0    241319  2017-01-02 13:35:40       44.99  Cancelled
# 1    241423  2017-11-06 13:10:02      136.15  Completed
# 2    242832  2017-12-31 17:40:03       15.76  Completed
# 3    243330  2017-02-16 10:59:38       84.98  Completed
# 4    243784  2017-11-24 13:35:19      157.86  Cancelled

# %%
orders.tail()
# Out:
#         order_id         created_date  total_paid            state
# 226904    527397  2018-03-14 13:56:38       42.99      Place Order
# 226905    527398  2018-03-14 13:57:25       42.99  Shopping Basket
# 226906    527399  2018-03-14 13:57:34      141.58  Shopping Basket
# 226907    527400  2018-03-14 13:57:41       19.98  Shopping Basket
# 226908    527401  2018-03-14 13:58:36       18.98      Place Order

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226909 entries, 0 to 226908
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      226909 non-null  int64
#  1   created_date  226909 non-null  object
#  2   total_paid    226904 non-null  float64
#  3   state         226909 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.9+ MB

# %%
orders.describe().round()
# Out:
#        order_id  total_paid
# count  226909.0    226904.0
# mean   413296.0       569.0
# std     65919.0      1762.0
# min    241319.0         0.0
# 25%    356263.0        34.0
# 50%    413040.0       113.0
# 75%    470553.0       526.0
# max    527401.0    214748.0

# %%
orders.nunique()
# Out:
# order_id        226909
# created_date    224828
# total_paid       31236
# state                5
# dtype: int64

# %%
orders['state'].unique()
# Out:
# array(['Cancelled', 'Completed', 'Pending', 'Shopping Basket',
#        'Place Order'], dtype=object)

# %%
orders.isna().sum()
# Out:
# order_id        0
# created_date    0
# total_paid      5
# state           0
# dtype: int64

# %% [markdown]
# ####First problem in Orders

# %%
# Pending means the order is awaiting payment confirmation but normally the total_paid is not empty
orders.query('total_paid.isna()')
# Out:
#         order_id         created_date  total_paid    state
# 127701    427314  2017-11-20 18:54:39         NaN  Pending
# 132013    431655  2017-11-22 12:15:24         NaN  Pending
# 147316    447411  2017-11-27 10:32:37         NaN  Pending
# 148833    448966  2017-11-27 18:54:15         NaN  Pending
# 149434    449596  2017-11-27 21:52:08         NaN  Pending

# %%
orders.query('state == "Pending"')
# Out:
#         order_id         created_date  total_paid    state
# 7         245851  2017-04-04 20:58:21       79.99  Pending
# 17        252371  2017-02-09 12:31:57       27.98  Pending
# 24        254537  2017-05-23 19:58:30      102.97  Pending
# 27        256434  2018-02-26 07:32:21       39.99  Pending
# 32        258087  2017-02-28 19:15:24       84.73  Pending
# ...          ...                  ...         ...      ...
# 226877    527370  2018-03-14 13:47:00       19.98  Pending
# 226880    527373  2018-03-14 13:44:45       31.38  Pending
# 226886    527379  2018-03-14 13:50:49        9.99  Pending
# 226898    527391  2018-03-14 13:57:54       54.98  Pending
# 226899    527392  2018-03-14 13:55:11       34.99  Pending
#
# [14379 rows x 4 columns]

# %%
orders.duplicated().sum()
# Out:
# 0

# %%
orders.nlargest(5, "total_paid")
# Out:
#         order_id         created_date  total_paid            state
# 96028     395611  2017-09-01 20:56:34   214747.53  Shopping Basket
# 2478      301934  2017-01-03 19:27:13   214746.63  Shopping Basket
# 183927    484334  2018-01-07 15:58:26   214714.31  Shopping Basket
# 61659     361200  2017-06-01 11:55:02   214642.47  Shopping Basket
# 40557     340045  2017-03-28 13:27:52   214517.58  Shopping Basket

# %%
orders.query('state == "Completed"').nlargest(5, "total_paid")
# Out:
#         order_id         created_date  total_paid      state
# 147938    448053  2017-11-27 12:59:51    13387.78  Completed
# 95399     394981  2017-08-31 13:09:05    10586.97  Completed
# 40247     339735  2017-03-27 16:57:34     9987.76  Completed
# 34178     333662  2017-04-12 13:33:22     9423.90  Completed
# 133774    433435  2017-11-24 12:17:33     9080.16  Completed

# %%
orders.nsmallest(5, "total_paid")
# Out:
#      order_id         created_date  total_paid            state
# 150    296010  2017-01-09 23:47:00         0.0        Completed
# 264    299605  2017-01-01 10:33:46         0.0  Shopping Basket
# 308    299651  2017-01-01 12:23:58         0.0  Shopping Basket
# 377    299731  2017-01-01 14:52:18         0.0  Shopping Basket
# 380    299734  2017-01-01 14:55:20         0.0  Shopping Basket

# %%
# 16 orders completed with a basket of 0 euro
orders.query('state == "Completed"').nsmallest(20,"total_paid")
# Out:
#         order_id         created_date  total_paid      state
# 150       296010  2017-01-09 23:47:00        0.00  Completed
# 2061      301495  2017-01-03 12:22:02        0.00  Completed
# 30427     329911  2017-02-27 18:21:01        0.00  Completed
# 61224     360765  2017-05-30 23:28:57        0.00  Completed
# 61902     361443  2017-06-01 23:21:54        0.00  Completed
# 61977     361518  2017-06-02 06:18:27        0.00  Completed
# 63610     363153  2017-06-07 13:39:13        0.00  Completed
# 65940     365485  2017-06-14 10:37:02        0.00  Completed
# 82898     382473  2017-07-26 18:23:09        0.00  Completed
# 82938     382513  2017-07-26 19:23:21        0.00  Completed
# 83327     382902  2017-07-28 16:37:37        0.00  Completed
# 84934     384509  2017-07-31 17:01:12        0.00  Completed
# 98470     398054  2017-09-09 00:14:12        0.00  Completed
# 106762    406347  2017-09-30 11:39:42        0.00  Completed
# ...

# %%
orders.query("total_paid == 0.0 & state == 'Completed'").nunique()
# Out:
# order_id        16
# created_date    16
# total_paid       1
# state            1
# dtype: int64

# %%
orders.query('state == "Shopping Basket"').nsmallest(50,"total_paid")
# Out:
#       order_id         created_date  total_paid            state
# 264     299605  2017-01-01 10:33:46         0.0  Shopping Basket
# 308     299651  2017-01-01 12:23:58         0.0  Shopping Basket
# 377     299731  2017-01-01 14:52:18         0.0  Shopping Basket
# 380     299734  2017-01-01 14:55:20         0.0  Shopping Basket
# 412     299767  2017-01-01 16:12:41         0.0  Shopping Basket
# 439     299796  2017-01-01 17:08:48         0.0  Shopping Basket
# 468     299827  2017-01-01 17:46:00         0.0  Shopping Basket
# 478     299839  2017-01-01 18:07:11         0.0  Shopping Basket
# 481     299842  2017-01-01 18:15:50         0.0  Shopping Basket
# 532     299893  2017-01-01 19:26:33         0.0  Shopping Basket
# 551     299913  2017-01-01 19:45:20         0.0  Shopping Basket
# 572     299938  2017-01-01 20:21:01         0.0  Shopping Basket
# 576     299943  2017-01-01 20:30:14         0.0  Shopping Basket
# ...

# %%
orders.query('created_date.between("2016-12-30", "2017-01-02")')
# Out:
#      order_id         created_date  total_paid            state
# 8      245941  2017-01-01 10:32:23      183.52        Completed
# 114    287780  2017-01-01 21:32:41       94.23        Completed
# 138    293308  2017-01-01 13:33:43     2635.47        Completed
# 144    294810  2017-01-01 19:21:56      476.49        Cancelled
# 147    295347  2017-01-01 02:02:38       72.19        Completed
# ..        ...                  ...         ...              ...
# 743    300119  2017-01-01 23:51:43       94.99  Shopping Basket
# 744    300120  2017-01-01 23:51:51       36.98      Place Order
# 746    300122  2017-01-01 23:54:42        0.00  Shopping Basket
# 749    300127  2017-01-01 23:58:36      739.99  Shopping Basket
# 750    300128  2017-01-01 23:58:51     1193.99  Shopping Basket
#
# [548 rows x 4 columns]

# %%
orders.query('created_date.between("2016-12-30", "2017-01-02")').sort_values('total_paid', ascending=True)
# Out:
#      order_id         created_date  total_paid            state
# 434    299790  2017-01-01 17:03:53        0.00      Place Order
# 377    299731  2017-01-01 14:52:18        0.00  Shopping Basket
# 511    299872  2017-01-01 18:58:49        0.00      Place Order
# 590    299958  2017-01-01 20:46:05        0.00  Shopping Basket
# 380    299734  2017-01-01 14:55:20        0.00  Shopping Basket
# ..        ...                  ...         ...              ...
# 165    297148  2017-01-01 16:42:24     4069.54        Completed
# 491    299852  2017-01-01 18:30:05     4467.95  Shopping Basket
# 259    299600  2017-01-01 11:56:17     4607.62        Completed
# 461    299820  2017-01-01 17:38:15     6029.99  Shopping Basket
# 255    299596  2017-01-01 09:53:11     8039.96  Shopping Basket
#
# [548 rows x 4 columns]

# %%
orders.query('created_date.between("2016-12-30", "2017-01-02") & state == "Completed"').sort_values('total_paid', ascending=True)
# Out:
#      order_id         created_date  total_paid      state
# 354    299704  2017-01-01 13:49:09       17.98  Completed
# 171    297809  2017-01-01 12:07:38       18.23  Completed
# 208    299546  2017-01-01 01:57:34       18.99  Completed
# 612    299981  2017-01-01 21:19:43       21.13  Completed
# 424    299780  2017-01-01 16:55:22       22.18  Completed
# ..        ...                  ...         ...        ...
# 539    299901  2017-01-01 19:47:54     1986.99  Completed
# 138    293308  2017-01-01 13:33:43     2635.47  Completed
# 180    298391  2017-01-01 12:18:28     2919.98  Completed
# 165    297148  2017-01-01 16:42:24     4069.54  Completed
# 259    299600  2017-01-01 11:56:17     4607.62  Completed
#
# [114 rows x 4 columns]

# %%
orders.query('order_id == 406745	')
# Out:
#         order_id         created_date  total_paid      state
# 107160    406745  2017-09-30 19:20:47         0.0  Completed

# %%
orders.query('state == "Shopping Basket"').nunique()
# Out:
# order_id        117809
# created_date    116909
# total_paid       18897
# state                1
# dtype: int64

# %%
orders.drop_duplicates(['order_id'])
# Out:
#         order_id         created_date  total_paid            state
# 0         241319  2017-01-02 13:35:40       44.99        Cancelled
# 1         241423  2017-11-06 13:10:02      136.15        Completed
# 2         242832  2017-12-31 17:40:03       15.76        Completed
# 3         243330  2017-02-16 10:59:38       84.98        Completed
# 4         243784  2017-11-24 13:35:19      157.86        Cancelled
# ...          ...                  ...         ...              ...
# 226904    527397  2018-03-14 13:56:38       42.99      Place Order
# 226905    527398  2018-03-14 13:57:25       42.99  Shopping Basket
# 226906    527399  2018-03-14 13:57:34      141.58  Shopping Basket
# 226907    527400  2018-03-14 13:57:41       19.98  Shopping Basket
# 226908    527401  2018-03-14 13:58:36       18.98      Place Order
#
# [226909 rows x 4 columns]

# %% [markdown]
# #BRANDS TABLE INFOS

# %%
brands
# Out:
#     short       long
# 0     8MO  8Mobility
# 1     ACM       Acme
# 2     ADN     Adonit
# 3     AII      Aiino
# 4     AKI     Akitio
# ..    ...        ...
# 182   XOO     Xoopar
# 183   XRI     X-Rite
# 184   XTO      Xtorm
# 185   ZAG   ZaggKeys
# 186   ZEP       Zepp
#
# [187 rows x 2 columns]

# %%
brands.size
# Out:
# 374

# %%
brands.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   short   187 non-null    object
#  1   long    187 non-null    object
# dtypes: object(2)
# memory usage: 3.0+ KB

# %% [markdown]
# ####Issue with long ref / might be related with products table
# RELATED WITH PRODUCTS

# %%
brands.describe()
# Out:
#        short    long
# count    187     187
# unique   187     181
# top      8MO  Mophie
# freq       1       2

# %%
brands.nunique()
# Out:
# short    187
# long     181
# dtype: int64

# %%
# Duplicates long ref
brands.loc[brands['long'].duplicated()]
# Out:
#     short      long
# 7     APP     Apple
# 19    CAD      Bose
# 70    KEN   Jaybird
# 80    LIB   Unknown
# 98    MUJ    Mophie
# 153   STA  Startech

# %%
# Might be a problem with references in others tables
brands.query('long == "Apple" |long == "Bose" | long == "Jaybird" | long == "Mophie" | long == "Startech"|long == "Unknown"')
# Out:
#     short      long
# 6     AP2     Apple
# 7     APP     Apple
# 17    BOS      Bose
# 19    CAD      Bose
# 37    ENV   Unknown
# 67    JYB   Jaybird
# 70    KEN   Jaybird
# 80    LIB   Unknown
# 94    MOP    Mophie
# 98    MUJ    Mophie
# 117   OTR  Startech
# 153   STA  Startech

# %% [markdown]
# AP2 = Apple(refurbished-2de hand) (ok)\
# CAD = empty tab\
# ENV = empty tab\
# KEN = Kensington\
# LIB = empty tab\
# OTR = mix multiple brands (worst one)

# %%
products.loc[products['sku'].str.contains('KEN')].head()
# Out:
#          sku                                            name  \
# 41   KEN0028            Kensington ClickSafe lock Mac and PC
# 86   KEN0045    Kensington Essentials Stand iPad Stand black
# 87   KEN0046    Kensington Essentials Stand iPad Stand white
# 355  KEN0059  Kensington Soft Case cover iPhone 5 / 5S black
# 356  KEN0062    Kensington Thin Back Case iPhone 5 / 5S Gray
#
#                                     desc  price promo_price  in_stock  \
# 41         Mac and PC padlock with keys.  54.99     499.899         0
# 86   Universal support for iPad tablets.  29.99     139.876         0
# 87   Universal support for iPad tablets.  19.99     128.986         0
# 355             Soft Case iPhone 5 / 5S.  14.99      89.903         0
# 356             Back Case iPhone 5 / 5S.  19.99      99.946         0
#
#          type
# 41       1325
# 86       1216
# 87       1216
# 355  11865403
# 356  11865403

# %%
# issue with long KEN = Kensington and not Jaybird
products.loc[products['sku'].str.contains('KEN')].head()
# Out:
#          sku                                            name  \
# 41   KEN0028            Kensington ClickSafe lock Mac and PC
# 86   KEN0045    Kensington Essentials Stand iPad Stand black
# 87   KEN0046    Kensington Essentials Stand iPad Stand white
# 355  KEN0059  Kensington Soft Case cover iPhone 5 / 5S black
# 356  KEN0062    Kensington Thin Back Case iPhone 5 / 5S Gray
#
#                                     desc  price promo_price  in_stock  \
# 41         Mac and PC padlock with keys.  54.99     499.899         0
# 86   Universal support for iPad tablets.  29.99     139.876         0
# 87   Universal support for iPad tablets.  19.99     128.986         0
# 355             Soft Case iPhone 5 / 5S.  14.99      89.903         0
# 356             Back Case iPhone 5 / 5S.  19.99      99.946         0
#
#          type
# 41       1325
# 86       1216
# 87       1216
# 355  11865403
# 356  11865403

# %%
brands.query('long == "Kensington"')
# Out:
# Empty DataFrame
# Columns: [short, long]
# Index: []

# %%
brands.isna().sum()
# Out:
# short    0
# long     0
# dtype: int64

# %% [markdown]
# #PRODUCTS TABLE INFO

# %%
products
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99     499.899
# ...

# %%
products.shape
# Out:
# (19326, 7)

# %%
products.head()
# Out:
#        sku                                           name  \
# 0  RAI0007              Silver Rain Design mStand Support
# 1  APP0023              Apple Mac Keyboard Keypad Spanish
# 2  APP0025               Mighty Mouse Apple Mouse for Mac
# 3  APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4  KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
#
#                                                 desc  price promo_price  \
# 0       Aluminum support compatible with all MacBook  59.99     499.899
# 1          USB ultrathin keyboard Apple Mac Spanish.     59     589.996
# 2                             mouse Apple USB cable.     59     569.898
# 3              IPhone dock and USB Cable Apple iPod.     25     229.997
# 4  2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.99
#
#    in_stock      type
# 0         1      8696
# 1         0  13855401
# 2         0      1387
# 3         0      1230
# 4         1      1364

# %%
products.loc[products['sku'].str.contains('KEN')]
# Out:
#              sku                                               name  \
# 41       KEN0028               Kensington ClickSafe lock Mac and PC
# 86       KEN0045       Kensington Essentials Stand iPad Stand black
# 87       KEN0046       Kensington Essentials Stand iPad Stand white
# 355      KEN0059     Kensington Soft Case cover iPhone 5 / 5S black
# 356      KEN0062       Kensington Thin Back Case iPhone 5 / 5S Gray
# ...          ...                                                ...
# 15146  KEN0237-A  Open - Kensington USB-C USB 3.1 ports Dock / U...
# 15251    KEN0247      CV2000V Kensington USB-C to VGA Full HD Black
# 15255    KEN0248  CV4000H Kensington USB adapter to HDMI 4K-C Black
# 17024    KEN0249  Kensington Security Locking Station 2.0 Adapte...
# 17652  KEN0239-A  Open - Kensington USB Dock SD1500-C to USB 3.0...
#
#                                                     desc   price promo_price  \
# ...

# %%
products.sort_values(by='promo_price', ascending=True)[['price', 'promo_price']]
# Out:
#          price promo_price
# 17320   124.99   1.003.978
# 2064    109.99   1.007.942
# 11236  1140.55   1.008.368
# 11237  1140.55   1.008.368
# 17125   119.99   1.010.414
# ...        ...         ...
# 19050  999.944     999.944
# 2649       120     999.944
# 2404     99.99     999.944
# 11809  1192.97      999.99
# 2206      1099      999.99
#
# [19326 rows x 2 columns]

# %% [markdown]
# ####Frist problem with products table
# -- value of promo_price > price

# %%
products.query('promo_price > price')
# Out:
#            sku                                          name  \
# 15     MOS0021          Clearguard Moshi MacBook Pro and Air
# 17     HGD0007  Henge Docks Docking Station MacBook Pro 13 "
# 19     APP0234                   Apple Dock Connector to VGA
# 23     MOB0007       Mobee Magic Charger Charger Magic Mouse
# 39     JMO0026   Just Mobile Lazy Couch Support Mac and iPad
# ...        ...                                           ...
# 19312  REP0424                  Input repair Headphones iPad
# 19313  REP0421                iPad charging connector repair
# 19314  REP0416                      iPad front camera repair
# 19315  REP0413                       repair rear camera iPad
# 19316  REP0407                           iPad battery repair
#
#                                                     desc      price  \
# 15     Keyboard Protector MacBook Pro 13-inch Retina ...      24.95
# 17     Dock and support with multiple connections for...      69.99
# ...

# %%
products.loc[products['sku'].str.contains('REP')].sort_values(by='price', ascending=False)
# Out:
#            sku                                       name  \
# 15391  REP0313               Full screen repair iPhone 6s
# 15432  REP0209                 iPad 2 Touch Screen Repair
# 15514  REP0389                 Repair Touch Screen iPad 3
# 388    REP0073  Repair Touch Screen iPad (1st generation)
# 15390  REP0300           Full screen repair iPhone 6 Plus
# ...        ...                                        ...
# 15392  REP0323          Full screen repair iPhone 6s Plus
# 15383  REP0379              LCD Screen Repair iPad Mini 3
# 15518  REP0392                 LCD screen repair iPad Air
# 15431  REP0378            Touch Screen Repair iPad Mini 3
# 15381  REP0340                   LCD screen repair iPad 4
#
#                                                     desc      price  \
# 15391  Repair service including parts and labor for i...      99.99
# 15432  Repair service including parts and labor for i...      99.99
# ...

# %%
products.query('sku == "REP0313"')['price'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# #### Second problem
# -- Unit_price or promo_price not matching price in orderslines df

# %%
orderslines.query('sku == "MOS0021"')
# Out:
#             id  id_order  product_id  product_quantity      sku unit_price  \
# 1273   1121690    300718           0                 1  MOS0021      19.99
# 1545   1122294    300976           0                 1  MOS0021      19.99
# 2514   1124261    301928           0                 1  MOS0021      19.99
# 3206   1129845    302470           0                 1  MOS0021      19.99
# 4077   1131569    303301           0                 1  MOS0021      19.99
# 5920   1135562    305020           0                 1  MOS0021      19.99
# 7282   1138479    306226           0                 1  MOS0021      19.99
# 7704   1139416    306600           0                 1  MOS0021      19.99
# 9419   1143044    308136           0                 1  MOS0021      19.99
# 10596  1145544    309185           0                 1  MOS0021      19.99
# 11000  1146260    309526           0                 1  MOS0021      19.99
# ...

# %%
orderslines.query('sku == "MOS0021"')['unit_price'].drop_duplicates()
# Out:
# 1273     19.99
# 20079    18.99
# 31504    24.99
# Name: unit_price, dtype: object

# %%
orderslines.query('sku == "MOS0021"')['unit_price'].unique()
# Out:
# array(['19.99', '18.99', '24.99'], dtype=object)

# %%
orderslines.query('sku == "JMO0026"')['unit_price'].drop_duplicates()
# Out:
# 47799    19.99
# Name: unit_price, dtype: object

# %%
len(products)
# Out:
# 19326

# %%
products.drop_duplicates(inplace=True)

# %%
len(products)
# Out:
# 10580

# %% [markdown]
# #COOKING

# %%
orderslines
# Out:
#              id  id_order  product_id  product_quantity      sku unit_price  \
# 0       1119109    299539           0                 1  OTT0133      18.99
# 1       1119110    299540           0                 1  LGE0043     399.00
# 2       1119111    299541           0                 1  PAR0071     474.05
# 3       1119112    299542           0                 1  WDT0315      68.39
# 4       1119113    299543           0                 1  JBL0104      23.74
# ...         ...       ...         ...               ...      ...        ...
# 293978  1650199    527398           0                 1  JBL0122      42.99
# 293979  1650200    527399           0                 1  PAC0653     141.58
# 293980  1650201    527400           0                 2  APP0698       9.99
# 293981  1650202    527388           0                 1  BEZ0204      19.99
# 293982  1650203    527401           0                 1  APP0927      13.99
#
#                        date
# ...

# %%
orderslines.loc[orderslines['sku'].str.contains('REP')]
# Out:
#              id  id_order  product_id  product_quantity      sku unit_price  \
# 320     1119714    299838           0                 1  REP0151      47.41
# 771     1120586    300269           0                 1  REP0239      59.90
# 1033    1121164    300497           0                 1  REP0134      89.99
# 1095    1121342    300556           0                 1  REP0060      39.91
# 1490    1122180    300923           0                 2  REP0060      39.91
# ...         ...       ...         ...               ...      ...        ...
# 292052  1646712    525751           0                 1  REP0308      59.99
# 292694  1647938    526281           0                 1  REP0270      49.99
# 293232  1648823    526697           0                 1  REP0216      39.99
# 293942  1650146    527367           0                 1  REP0250      69.90
# 293944  1650149    527367           0                 1  REP0299      59.99
#
#                        date
# ...

# %%
orderslines.loc[orderslines['sku'].str.contains('REP0156')]
# Out:
#              id  id_order  product_id  product_quantity      sku unit_price  \
# 135811  1386696    416760           0                 1  REP0156      68.99
#
#                        date
# 135811  2017-10-24 14:57:25

# %%
orderslines.loc[orderslines['sku'].str.contains('APP0367')]
# Out:
#              id  id_order  product_id  product_quantity      sku unit_price  \
# 12593   1149516    310929           0                 1  APP0367     119.00
# 30951   1185975    326580           0                 1  APP0367     109.99
# 31035   1186130    326650           0                 1  APP0367     109.99
# 57539   1234500    348672           0                 1  APP0367     109.99
# 73345   1262271    362696           0                 2  APP0367     109.99
# 74936   1264974    364048           0                 1  APP0367     109.99
# 98176   1306717    384043           0                 1  APP0367     109.99
# 106130  1320947    390877           0                 1  APP0367     106.99
# 106904  1322350    391563           0                 1  APP0367     106.99
# 107481  1323359    392068           0                 1  APP0367     106.99
# 114584  1348440    398073           0                 1  APP0367     106.99
# ...

# %%
orderslines.loc[orderslines['sku'].str.contains('TOS0022')].tail(50)
# Out:
#              id  id_order  product_id  product_quantity      sku unit_price  \
# 175204  1459652    448947           0                 1  TOS0022     100.76
# 175495  1460206    449203           0                 1  TOS0022     100.76
# 175915  1460993    449498           0                 1  TOS0022     100.76
# 177444  1463390    449414           0                 1  TOS0022     107.75
# 181283  1467728    451736           0                 1  TOS0022     107.75
# 183520  1471174    453177           0                 1  TOS0022     107.75
# 192484  1482880    457576           0                 1  TOS0022     107.75
# 197474  1489454    460081           0                 1  TOS0022     107.75
# 199027  1491878    461108           0                 1  TOS0022     107.75
# 200439  1493695    461791           0                 1  TOS0022     107.75
# 200753  1494200    461996           0                 1  TOS0022     107.75
# ...

# %%
orderslines.loc[orderslines['sku'].str.contains('TOS0022'), 'unit_price'].agg()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-e1d9080babea> in <cell line: 1>()
# ----> 1 orderslines.loc[orderslines['sku'].str.contains('TOS0022'), 'unit_price'].agg()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in aggregate(self, func, axis, *args, **kwargs)
#    4603
#    4604         op = SeriesApply(self, func, convert_dtype=False, args=args, kwargs=kwargs)
# -> 4605         result = op.agg()
#    4606         return result
#    4607
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in agg(self)
#    1124
#    1125     def agg(self):
# -> 1126         result = super().agg()
#    1127         if result is None:
#    1128             f = self.f
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in agg(self)
#     170
#     171         if is_dict_like(arg):
# ...

# %%
# orders_cl.csv
url = "https://drive.google.com/file/d/1Tla62vfu__kCqvgypZyVt2S9VuC016yH/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
orders_cl = pd.read_csv(path)

# orderlines_cl.csv
url = "https://drive.google.com/file/d/1OhtkQS2fwOYdzfd-qPh7im35iLc-L9TA/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
orderlines_cl = pd.read_csv(path)

# products_cl.csv
url = "https://drive.google.com/file/d/1s7Lai4NSlsYjGEPg1QSOUJobNYVsZBOJ/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
products_cl = pd.read_csv(path)

# %%
from google.colab import files

orders_qu.to_csv("orders_qu.csv", index=False)
files.download("orders_qu.csv")

orderlines_qu.to_csv("orderlines_qu.csv", index=False)
files.download("orderlines_qu.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7a10e99f716d> in <cell line: 3>()
#       1 from google.colab import files
#       2
# ----> 3 orders_qu.to_csv("orders_qu.csv", index=False)
#       4 files.download("orders_qu.csv")
#       5
#
# NameError: name 'orders_qu' is not defined
